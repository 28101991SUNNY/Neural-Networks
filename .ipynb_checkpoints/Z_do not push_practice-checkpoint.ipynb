# %% [markdown]
#         Y^ = A (wTx + w0)
#
#        = A(w1x1 + w2x2 + ... + wdxd + w0)
#
#
#        softmax =                sigmoid(Zi)
#           (Zi)  ----------------------------------------
#                  sigmoid(Z1) + sigmoid(Z2) + sigmoid(Z3)
#
#                             e^Zi
#             p[yi]  = ------------------------
#                     sum
#                     class i   e^Zi
#                     1 to k
#
#
#
#
#
#
#
#
#     Forward Propogation :
#
#                a1 = A1(w1Tx + b1)
#                a2 = A2(w2Tx + b2)
#                a3 = A3(w3Tx + b3)
#
#              dot( X ,  w)  =  y^
#                 (n,d)       (n,k)
#                       (d,k)

# %%
df = pd.read_csv("spiral.csv")
df
# Out:
#            x1        x2  y
# 0    0.000000  0.000000  0
# 1   -0.000650  0.010080  0
# 2    0.009809  0.017661  0
# 3    0.007487  0.029364  0
# 4   -0.000027  0.040404  0
# ..        ...       ... ..
# 295 -0.829548  0.482363  2
# 296 -0.753207  0.610731  2
# 297 -0.631949  0.748762  2
# 298 -0.581099  0.801389  2
# 299 -0.476268  0.879300  2
#
# [300 rows x 3 columns]

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#            x1        x2
# 0    0.000000  0.000000
# 1   -0.000650  0.010080
# 2    0.009809  0.017661
# 3    0.007487  0.029364
# 4   -0.000027  0.040404
# ..        ...       ...
# 295 -0.829548  0.482363
# 296 -0.753207  0.610731
# 297 -0.631949  0.748762
# 298 -0.581099  0.801389
# 299 -0.476268  0.879300
#
# [300 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 295    2
# 296    2
# 297    2
# 298    2
# 299    2
# Name: y, Length: 300, dtype: int64

# %%
d = X.shape[1]
n = X.shape[0]
k = len(np.unique(y))

# %%
y = pd.get_dummies(y).to_numpy()

# %%
n,d,k
# Out:
# (300, 2, 3)

# %%
# W = np.random.randn(d,k)

# %%
# W

# %%
# b = np.zeros((1,k))

# %%
# b

# %%
# Z = np.dot(X,W) + b

# %%
# Z.shape

# %%
def sigmoid(x):
    return 1/ (1+np.exp(-x))

# %%
# sigmoid(0)

# %%
# sigmoid(Z)

# %%
# probs = np.exp(Z) / np.sum(np.exp(Z),axis = 1,keepdims=True)
# probs

# %% [raw]
#                            n
#             J(w,w0) = 1/n sum  -yi*log(softmax(wTxi + w0))
#                           i=1

# %%
# categorical cross entropy 

# Loss = -np.sum(y * np.log(probs),axis=  1)
# Loss.shape

# %%
# Loss

# %% [markdown]
#         dJ = dJ  dA  dZ
#         dw   dA  dZ  dw
#
#
#
#         J(w,w0) = -1/n sum (-y*log(A)-(1-y)log(1-A))
#
#         A = A(Z)
#         Z = wTx+ w0
#
#
#
#         dJ = d  [-ylog(A)-(1-y)log(1-A)]
#         dA   dA
#
#
#            =  -y - (1-y)(-1)
#                A   (1-A)
#            =  -y - (1-y)/
#                A    (A-1)
#
#         dA = d ( 1/ 1+e^-z )
#         dZ  dZ
#
#            =  A(1-A)
#
#         dZ = X
#         dW
#
#         dZ = 1
#         db
#
#
#                 now
#                 dJ = dJ  dA  dZ
#                 dw   dA  dZ  dw
#
#                    = dJ dZ
#                      dZ dw
#
#                    = -[y/A + (1-y)/(A-1)]*[A(1-a)]  * dZ
#                                                       dw
#                 dJ = (A-y) dZ
#                 dw         dW
#
#
#
#                 wNew = wOld - eta * dJ/dW
#
#                 bNew = bOld - eta * dJ/db
#
#          same derivation works out for softmax
#
#          softmax' = sigmoid'

# %%
n,d = X.shape
n,d
# Out:
# (300, 2)

# %%
k = y.shape[-1]
k
# Out:
# 3

# %%
w = 0.01*np.random.randn(d,k)
w
# Out:
# array([[-0.00242472, -0.00674177,  0.01036256],
#        [-0.01037708,  0.00604413,  0.00848062]])

# %%
b = np.zeros((1,k))
b
# Out:
# array([[0., 0., 0.]])

# %%
# Z = np.dot(X,w) + b

# %%
# probs = np.exp(Z) / np.sum(np.exp(Z),axis = 1,keepdims=True)

# %%
# probs.shape, Z.shape

# %%
# Loss = np.mean((-(y*np.log(probs))).sum(axis = 1))
# Loss

# %% [raw]
#             now
#             dJ = dJ  dA  dZ
#             dw   dA  dZ  dw
#
#                = dJ dZ
#                  dZ dw
#
#                = -[y/A + (1-y)/(A-1)]*[A(1-a)]  * dZ
#                                                   dw
#             dJ = (A-y) dZ
#             dw         dW

# %%
# dJ_dZ = probs-y

# %%
# X.T.shape,dJ_dZ.shape

# %%
# dJ_dw = np.dot(X.T,dJ_dZ ) / n

# %%
# dJ_dw

# %%
# dJ_db = dJ_dZ.sum(axis = 0,keepdims=True)

# %%
# dJ_db

# %%
# dJ_dw.shape,dJ_db.shape

# %%
def backward_propogation(probs,y):
    dJ_dZ = probs-y
    n = len(y)
    dJ_dZ = dJ_dZ/n
    dJ_dw = np.dot(X.T,dJ_dZ ) 
    dJ_db = dJ_dZ.sum(axis = 0,keepdims=True)
    return dJ_dw,dJ_db

# %%
# backward_propogation(probs,y)

# %%
max_iter = 200
lr = 1
loss = []
for i in range(max_iter):
    
    Z = np.dot(X,w) + b
    
    probs = np.exp(Z) / np.sum(np.exp(Z),axis = 1,keepdims=True)
    
    L = np.mean((-(y*np.log(probs))).sum(axis = 1))
    if i % 10 == 0:
        print(f"iteration: {i}, loss: {L}")
    loss.append(L)

    dJ_dw,dJ_db = backward_propogation(probs,y)
    
    w = w - lr* dJ_dw
    b = b - lr* dJ_db
# Out:
# iteration: 0, loss: 1.098654348552027
# iteration: 10, loss: 0.9007114692456012
# iteration: 20, loss: 0.8263500552630826
# iteration: 30, loss: 0.7918932900526581
# iteration: 40, loss: 0.7734754265259493
# iteration: 50, loss: 0.7626546653496658
# iteration: 60, loss: 0.7558679768857797
# iteration: 70, loss: 0.7514056481691861
# iteration: 80, loss: 0.7483660479767856
# iteration: 90, loss: 0.7462384536022573
# iteration: 100, loss: 0.7447170076555133
# iteration: 110, loss: 0.7436102287693508
# iteration: 120, loss: 0.7427938404259227
# iteration: 130, loss: 0.7421847519331933
# iteration: 140, loss: 0.7417260172035591
# iteration: 150, loss: 0.7413777883754087
# iteration: 160, loss: 0.7411116875165576
# iteration: 170, loss: 0.7409072008987647
# iteration: 180, loss: 0.7407493093607448
# iteration: 190, loss: 0.7406268958438426

# %%
w,b
# Out:
# (array([[ 1.34898064,  0.99748212, -2.34526669],
#         [-2.76711589,  3.1529523 , -0.38168873]]),
#  array([[-0.04408994, -0.01606068,  0.06015062]]))

# %%
plt.plot(loss)

# %% [markdown]
#
#         X             Z1      A1         Z2       A2      J(y,A2)
#        dZ1/dW1    dA1/dZ1   dZ2/dA1   dA2/dZ2    dJ/dA2
#        dZ1/db1               dZ2/dw2
#                              dZ2/db2
#
#
#        if 4 neurons in the hiddne layer
#        and 3 classs classification
#
#        two features
#        d = 2
#        k = 3
#        n = 300
#
#
#        300,2              300,4                           300,3
#         X             Z1      A1         Z2        A2      J(y,A2)
#                   dA1/dZ1    dZ2/dA1   dA2/dZ2    dJ/dA2
#        dZ1/dW1
#        dZ1/db1               dZ2/dw2
#                              dZ2/db2
#
#
#                X: 300,2       A1 (300,4)       A2 (300,3)
#                      Z1: 300,4          Z2 : 300,3
#
#                      w1 : 2,4         w2:(4,3)
#                      b1 : 1,4         b3:(1,3)

# %% [markdown]
#     z1= dot(w1.x) + b1
#
#     A1 = max(0,Z1)
#
#     Z2 = dot(w2.A1) + b2
#
#     A2 = softmax(0,Z2)

# %% [markdown]
#        300,3
#
#             w1 2,4            w2 4,3
#             b1 1,4            b2 1,3
#
#
#
#
#                  Z1 | A1
#                               Z2 | A2
#         X1       Z1 | A1
#                               Z2 | A2        J
#         X2       Z1 | A1
#                               Z2 | A2
#                  Z1 | A1
#
#
#
#                  dA1  dZ2     dA2  dJ
#                  dZ1  dA1     dZ2  dA2
#
#         dZ1 dZ1            dZ2 dZ2
#         dw1 db1            dw2 db2
#
#
#                 dJ_dZ = (A2-y)      ----------------------
#                       (300,3)
#
#             dZ2_dw2 = A1
#             dZ2_db2 =  1
#
#             A2-y = (A2-y)/n
#                                             A2-y    A1
#             dJ_dw2 = dot(A1.T,(A2-y))      300,3  300,4 -----------
#             dJ_db2 = (A2-y), sum axis = 0
#
#
#
#             now
#
#             dZ2_dA1 = d ((w2.A1) + b2)
#                      dA1
#
#                     = w2
#
#             dJ_dA1  = (A2-y)*w2         ------------------
#
#
#              dA1_dZ1 = d/dZ1  (max(0,Z1))
#                     = if Z1 > 0 : 1
#                       if Z1 <=0 : 0
#
#                 dJ_dZ1 = (A2-y)*w2      : override   -------------
#                 dJ_dZ1[dJ_dZ1<0] = 0
#
#             dZ1_dw1 = d (Z1) = X
#                      dw1
#             dZ1_db1 = 1
#
#                dJ_dw1 = (dJ_dZ1)*X
#                dJ_db1 = (dJ_dZ1)

# %%
df = pd.read_csv("spiral.csv")
df
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

y = pd.get_dummies(y).to_numpy()

n,d = X.shape
n,d

k = y.shape[-1]
k

h = 4 # number of hidden layers 

w1 = 0.01*np.random.randn(d,h)
b1 = np.zeros((1,h))

w2 = 0.01*np.random.randn(h,k)
b2 = np.zeros((1,k))

# %%
print(n,d,k)
# Out:
# 300 2 3

# %%
w1,b1
# Out:
# (array([[-0.0090164 , -0.00159979, -0.01038217,  0.02091734],
#         [ 0.0029708 ,  0.01591439, -0.01061915, -0.00719239]]),
#  array([[0., 0., 0., 0.]]))

# %%
w2,b2
# Out:
# (array([[ 0.01271375, -0.00856524, -0.00871164],
#         [-0.00545287,  0.0071806 ,  0.00899113],
#         [-0.00717747, -0.00036546, -0.01757035],
#         [ 0.00199624, -0.00273776,  0.00783469]]),
#  array([[0., 0., 0.]]))

# %%
# Forward Propogation 
Z1 = np.dot(X,w1) + b1
A1 = np.maximum(0,Z1)    # Relu
Z2 = np.dot(A1,w2) + b2
A2 = np.exp(Z2) / (np.exp(Z2)).sum(axis = 1,keepdims = True) # Softmax

# %%
probs = A2

# %%
# Loss: 
loss = np.mean(-np.sum((y*np.log(probs)),axis = 1))
loss
# Out:
# 1.0986279161772017

# %%
# A1.shape

# %%
dJ_dZ = (probs-y) / n
dJ_dw2 = np.dot(A1.T,dJ_dZ)
dJ_db2 = np.sum(dJ_dZ,axis = 0,keepdims=True)

# %%
dJ_db2
# Out:
# array([[ 1.06418741e-06,  8.02369074e-07, -1.86655648e-06]])

# %%
dJ_dw2
# Out:
# array([[ 0.00037545,  0.00011271, -0.00048816],
#        [ 0.00060076, -0.00071241,  0.00011165],
#        [-0.00027852,  0.0007425 , -0.00046398],
#        [-0.00058442, -0.00015732,  0.00074175]])

# %%
dJ_dA1  = np.dot(dJ_dZ,w2.T)

# %%
# dJ_dA1.shape

dJ_dA1[dJ_dZ1<0] = 0
dJ_dZ1 = dJ_dA1

# %%
dJ_dZ1.shape
# Out:
# (300, 4)

# %%
X.T.shape
# Out:
# (2, 300)

# %%
dJ_dw1 = np.dot(X.T,dJ_dZ1)
dJ_db1 = dJ_dZ1.sum(axis = 0,keepdims =True)

# %%
df = pd.read_csv("spiral.csv")
df
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

y = pd.get_dummies(y).to_numpy()

n,d = X.shape
n,d

k = y.shape[-1]
k

h = 10 # number of hidden layers 

w1 = 0.01*np.random.randn(d,h)
b1 = np.zeros((1,h))

w2 = 0.01*np.random.randn(h,k)
b2 = np.zeros((1,k))

# %%
LossHistory = []
max_iter = 100
lr = 2.5
for i in range(max_iter):
        # Forward Propogation 
    Z1 = np.dot(X,w1) + b1
    A1 = np.maximum(0,Z1)    # Relu
    Z2 = np.dot(A1,w2) + b2
    A2 = np.exp(Z2) / (np.exp(Z2)).sum(axis = 1,keepdims = True) # Softmax

    probs = A2

    loss = np.mean(-np.sum((y*np.log(probs)),axis = 1))
    LossHistory.append(loss)

    dJ_dZ2 = (probs-y) / n
    
    dJ_dw2 = np.dot(A1.T,dJ_dZ2)
    dJ_db2 = np.sum(dJ_dZ2,axis = 0,keepdims=True)
    dJ_dA1  = np.dot(dJ_dZ2,w2.T)
    dJ_dA1[Z1<=0] = 0
    dJ_dZ1 = dJ_dA1
    dJ_dw1 = np.dot(X.T,dJ_dZ1)
    dJ_db1 = dJ_dZ1.sum(axis = 0,keepdims =True)   

    w1 = w1 - lr*dJ_dw1
    b1 = b1 - lr*dJ_db1

    w2 = w2 - lr*dJ_dw2
    b2 = b2 - lr*dJ_db2

plt.plot(LossHistory)

# %%
# LossHistory

# %%
df = pd.read_csv("spiral.csv")
df
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
class NN:
    
    def __init__(self, n_features, n_hidden, n_classes):
        self.d = n_features
        self.h = n_hidden
        self.n = n_classes
        self.W1 = 0.01 * np.random.randn(self.d, self.h)
        self.b1 = np.zeros((1,self.h))
        self.W2 = 0.01 * np.random.randn(self.h,self.n)
        self.b2 = np.zeros((1,self.n))
     
    def fwd_prop(self, X):
        Z1 = np.dot(X, self.W1) + self.b1
        A1 = np.maximum(0, Z1)
        Z2 = np.dot(A1, self.W2) + self.b2
        Z2 = np.exp(Z2)
        A2 = Z2 / np.sum(Z2, axis=1, keepdims=True)
        return A1, A2
    
    def cce_loss(self, y, probs):
        num_examples = y.shape[0]
        correct_logprobs = -np.log(probs[range(num_examples),y])
        loss = np.sum(correct_logprobs)/num_examples
        return loss  
    
    def back_prop(self, X, A1, A2, y):
        # compute the gradient on scores
        num_examples = y.shape[0]
        dZ2 = A2
        dZ2[range(num_examples),y] -= 1
        dZ2 /= num_examples
        # first backprop into parameters W2 and b2
        dW2 = np.dot(A1.T, dZ2)
        db2 = np.sum(dZ2, axis=0, keepdims=True)
        # next backprop into hidden layer, A1
        dA1 = np.dot(dZ2, self.W2.T)
        # backprop the ReLU non-linearity
        dA1[A1 <= 0] = 0
        # finally into W,b
        dZ1 = dA1
        dW1 = np.dot(X.T, dZ1)
        db1 = np.sum(dZ1, axis=0, keepdims=True)
        return dW1, db1, dW2, db2       
    
    def fit(self, X, lr, reg, max_iters):
        num_examples = X.shape[0]
        for i in range(max_iters):
            #foward prop
            A1, A2 = self.fwd_prop(X)
            # calculate loss
            data_loss = self.cce_loss(y, A2)
            reg_loss = 0.5*reg*np.sum(self.W1*self.W1) + 0.5*reg*np.sum(self.W2*self.W2)
            loss = data_loss + reg_loss
            
            if i % 1000 == 0:
                print("iteration %d: loss %f" % (i, loss))
        
            dW1, db1, dW2, db2  = self.back_prop(X, A1, A2, y)

            # add regularization gradient contribution
            dW2 += reg * self.W2
            dW1 += reg * self.W1

            # perform a parameter update
            self.W1 += -lr * dW1
            self.b1 += -lr * db1
            self.W2 += -lr * dW2
            self.b2 += -lr * db2
        
    def predict(self, X):
        A1 = np.maximum(0, np.dot(X, self.W1) + self.b1) # ReLU(Z1) = ReLU(W1T. X + b1)
        Z2 = np.dot(A1, self.W2) + self.b2 # Z2 = W2T.A1 + b2 => 3 probab
        y_hat = np.argmax(Z2, axis=1) # taking index of max probab
        return y_hat
    
nn_model = NN(n_features=2, n_hidden=100, n_classes=3)
nn_model.fit(X, lr=1, reg=1e-3, max_iters=100)
print('training accuracy: %.2f' % (np.mean(nn_model.predict(X) == y)))
# Out:
# iteration 0: loss 1.098483
