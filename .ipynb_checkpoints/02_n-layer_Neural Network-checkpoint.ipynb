# %% [markdown]
# # Recap  on LRU :

# %% [markdown]
# Logistic Regression,
# - The Optimization algorithm minimizes Logloss
#
# <br>
#
# We define Logloss as:
#
# - $Logloss (L) = min_{w_j}∑_{i=1}^n[-y_i log(\hat{y_i}) - (1-y_i)log(1-\hat{y_i}) ]$
#
#
# Where:
# - $\hat{y}$ is sigmoid function ($σ$) of $z = w^t x + b$
# - $w_j$ is the jth weight parameter
# - $n$ is the total number of samples
#
# <br>
#
# #### the goal of optimization algorithm :
# - Ans: to minimize logloss by finding the gradients
#
# <br>

# %% [markdown]
# ###  Derivative Rules
#
# Before we start to find derivatives, let recall some of the simple Derivation rules
#
#
# 1. **Power Derivative**
#
#  $$\frac{d x^{n}}{dx} = n.x^{n-1}$$
#
#  Similarly
#
#   $$\frac{d x^{-n}}{dx} = -n.x^{-(n+1)}$$
#
# 2. **Log Derivative**
#
# $$\frac{d log(x)}{dx} = \frac{1}{x}$$
#
#
# 3. **Exponential Derivative**
#
#  $$\frac{d e^{ax}}{dx} = a.e^{ax}$$
#
#  Similarly,
#
#  $$\frac{d e^{-ax}}{dx} = -a.e^{-ax}$$

# %% [markdown]
# ### Derivation of Sigmoid :
#
#
# #### Lets come back to our logloss ,
#
#
#  $$\hat{y} = σ(z)$$
#
#
# Where $σ(z)$:
# $$σ = \frac{1}{1+e^{-z} }$$
#
#
#
# $$σ=(1+e^{-z})^{-1}$$
#
# Lets substitute $(1+e^{-z})$  with $u$, thus
#
# $$σ=(u)^{-1}$$
#
# And lets use power rule here and take the derivative of sigmoid equation in terms $u$ w.r.t to $z$
#
#  $$\frac{d u^{-1}}{dz} = -u^{-2} . \frac{du}{dz}$$
#
#
#  Lets work seperately on calulcating $\frac{du}{dx}$
#
#
# $$\frac{du}{dz} = \frac{d (1+e^{-z})}{dz}$$
#
# On solving:
#
#
# $$\frac{du}{dz} = \frac{d(1)}{dz} + \frac{d (e^{-z})}{dz}$$
#
# First term, becomes zero.
#
#
# We already know that derivative of negative exponent $\frac{d e^{-ax}}{dx} = -a.e^{-ax}$
#
#
# $$\frac{du}{dz} = -e^{-z}$$
#
# Now subsituting the value of $\frac{du}{dz}$ to equation $σ'(z) = \frac{d u^{-1}}{dz} = -u^{-2} . \frac{du}{dz}$
#
# $$ σ'(z) = -u^{-2} . -e^{-z} $$
#
# Replacing $u$ with $1+e^{-z} $
#
#
# $$σ'(z) = \frac{1.e^{-z}}{(1+e^{-z})^{2}} $$
#
# Now rewriting the equation a bit
#
# $$σ'(z) = \frac{1}{1+e^{-z}} \frac{e^{-z}}{1+e^{-z}} $$
#
# And since 1-1 = 0 , we can do a little tweek in the equation
#
# $$σ'(z) = \frac{1}{1+e^{-z}} \frac{e^{-z}+1-1}{1+e^{-z}} $$
#
# Rewriting equation a bit
#
# $$σ'(z) = \frac{1}{1+e^{-z}} [ \frac{e^{-z}+1}{1+e^{-z}}-\frac{1}{1+e^{-z}}] $$
#
# Equation becomes:
#
# $$σ'(z) = \frac{1}{1+e^{-z}} [ 1 -\frac{1}{1+e^{-z}}] $$
#
# As we know $σ(z) = \frac{1}{1+e^{-z}}$, Equation becomes:
#
# $$σ'(z) = σ(z) [ 1 -σ(z)] $$

# %% [markdown]
# ### Gradient of LogLoss
#
# Now that we know sigmoid  is differentiable, lets find the gradient of the log-loss,
#
# log-loss is defined as:
# - $$Logloss (L) = min_{w_j}∑_{i=1}^n[-y_i log(\hat{y_i}) - (1-y_i)log(1-\hat{y_i}) ]$$
#
# - What all we know
#     - $$\frac{d log(x)}{dx} = \frac{1}{x}$$
#     - $$ σ'(z) = σ(z)(1-σ(z)) $$
#     - $$ \frac{\partial (w^Tx_i+w_0)}{\partial w_j} = x_{ij} $$
#
# Also recall chain rule
# - if $u = \sigma(z)$ , where $z = 3x $,then
# $$\frac{du}{dx} = \frac{du}{dz} * \frac{dz}{dx} $$
#
# -  Therefore $\frac{du}{dz} = \frac{d\sigma(z)}{dz} = \sigma(z)(1-\sigma(z))$
# - And $ \frac{dz}{dx} = \frac{d(3x)}{dx} = 3 $
# - hence final equation becomes:
# - $$\frac{du}{dx} = \sigma(z)(1-\sigma(z))  * 3 $$
#
# ---

# %% [markdown]
# With the same concept:
#
# $$\frac{\partial L}{\partial w_j} = \frac{\partial L}{\partial y_i ̂} * \frac{\partial y_i ̂}{\partial z_i} * \frac{\partial z_i}{\partial w_j} $$
#
# Now lets take $\frac{\partial L}{\partial \hat{y_i} }$:
# - $$ \frac{\partial L}{\partial \hat{y_i}} = -y_i \frac{\partial log(\hat{y_i})}{\partial \hat{y_i}} - (1-y_i) \frac{\partial log(1-\hat{y_i})}{\partial \hat{y_i}} $$
#
# As $\frac{d log x}{dx} = \frac{1}{x}$, therefore:
# -  $$ \frac{\partial L}{\partial \hat{y_i}} = -y_i \frac{1}{\hat{y_i}} - (1-y_i) \frac{-1}{(1-\hat{y_i})} $$
#
#
# Now the equation $\frac{\partial L}{\partial w_j}$ becomes:
#
# - $$ \frac{\partial L}{\partial \hat{w_j}} = -y_i \frac{1}{\hat{y_i}} \frac{\partial y_i ̂}{\partial z_i} * \frac{\partial z_i}{\partial w_j}  - (1-y_i) \frac{-1}{(1-\hat{y_i})} \frac{\partial y_i ̂}{\partial z_i} * \frac{\partial z_i}{\partial w_j} $$

# %% [markdown]
# Now we know  $ \hat{y_i}  =  σ(z) $,
#
# and $$\frac{σ(z)}{dz} =  σ(z)(1-σ(z)) = y_i ̂ (1- y_i ̂)$$
#
# - Therefore $$ \frac{\partial y_i ̂}{\partial z_i} = y_i ̂(1-y_i ̂) $$
#
#
# Subsituting it to our equation,
#
#
# - $$ \frac{\partial L}{\partial w_j} = -y_i\frac{1}{y_i ̂}* y_i ̂(1-y_i ̂) \frac{\partial z_i }{\partial w_j} + (1-y_i)\frac{1}{1-y_i ̂}*y_i ̂(1-y_i ̂) \frac{\partial z_i}{\partial w_j}$$
#
#
# On simplifying since we can cut some terms in the numerator and denominator
#
# -  $$ \frac{\partial L}{\partial w_j} = -y_i(1-y_i ̂) \frac{\partial z_i }{\partial w_j} + (1-y_i)*y_i ̂ \frac{\partial z_i}{\partial w_j}$$
#
# Now on opening the round brackets we get,
# - $$ \frac{\partial L}{\partial w_j} = -y_i\frac{\partial z_i }{\partial w_j} + y_i*y_i ̂ \frac{\partial z_i }{\partial w_j} + y_i ̂ \frac{\partial z_i}{\partial w_j} - y_i*y_i ̂ \frac{\partial z_i}{\partial w_j}$$
#
# Now on further solving, we get
# - $$ \frac{\partial L}{\partial w_j} = -y_i\frac{\partial z_i }{\partial w_j} + y_i ̂ \frac{\partial z_i}{\partial w_j}$$
# - $$ \frac{\partial L}{\partial w_j} = (y_i ̂-y_i) \frac{\partial z_i}{\partial w_j}$$
#
# Since $z_i = w^Tx_i+w_0$, $\frac{\partial z_i}{\partial w_j} = x_{ij}$
#
# Therefore equation becomes:
# - $$ \frac{\partial L}{\partial w_j} = \frac{1}{n}∑_{i=1}^{i=n}(y_i ̂-y_i) x_{ij}$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     For Softmax Linear Classifier
#
#     ForwardPropogation
#     X --> Z = wTx+b  --> y=A(Z)  >> loss(J) >>> BackwardPropogation
#                                                dJ_dA * dA_dZ * dZ_dW
#                                                dJ_dA * dA_dZ * dZ_db
#
#                                                dJ_dZ * dZ_dW
#                                                dJ_dZ * dZ_dW

# %%
class SoftmaxClassfier:
    
    def __init__(self,n_features , n_class):
        self.d = n_features
        self.k = n_class
        self.w = 0.01 * np.random.randn(d,k)
        self.b = np.zeros((1,k))
        self.loss = []
        
    def ForwardPropogation(self,X):
        Z = np.dot(X,self.w) + self.b
        exp_Z = np.exp(Z)
        probs = exp_Z / exp_Z.sum(axis = 1, keepdims =True)

        return probs
    
    
    def categorical_entropy(self,probs,y):
        y = pd.get_dummies(y).to_numpy()
        n = len(y)
        
        error = np.sum(np.sum(-(np.log(probs)*y),axis = 1)) / n
        
        return error
    
    
    def BackwardPropogation(self,probs,y):
        n = y.shape[0]
        y = pd.get_dummies(y).to_numpy()
                                          # dJ_dA * dA_dZ * dZ_dW
                                          # dJ_dA * dA_dZ * dZ_db

                                          # dJ_dZ * dZ_dW = (Yhat-Y)*X
                                          # dJ_dZ * dZ_dW = (Yhat-Y)*1
        dJ_dZ = (probs - y) / n
        
        dJ_dW = np.dot(X.T,dJ_dZ)
        dJ_db = np.sum(dJ_dZ,axis = 0 , keepdims=True)
        
        return dJ_dW, dJ_db

    def fit(self,X,y,lr = 0.1, max_iter = 100):
        
        for i in range(max_iter):
            
            probs = self.ForwardPropogation(X)
            
            loss = self.categorical_entropy(probs,y)
            dJ_dW,dJ_db = self.BackwardPropogation(probs,y)
            
            self.w = self.w - lr* dJ_dW
            self.b = self.b - lr* dJ_db
            
            self.loss.append(loss)
            
    def plot_loss(self):
        plt.plot(self.loss)
        plt.show()
    
    def predict(self,X):
        probs = self.ForwardPropogation(X)
        return np.argmax(probs,axis = 1)
    
    def Accuracy(self):
        
        return np.sum(self.predict(X) == y) / len(X)

# %% [markdown]
# # n-layer Neural Network

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#
#     Forward propogation :
#
#
#             Z1 = w1 X + b1
#
#             A1 = activation(Z1)
#
#                          after the first layer1 :
#
#                              for the next layers :
#                              input is the activation of the previous layers.
#                              which we can make them non-linear
#
#             Z2 = w2*A1 + b2
#
#             A2 = softmax(Z2)
#                = softmax( w2*(activation(w1.X + b1)) + b2 )
#                                   ^
#                                   ^
#                                   this is the step
#                                   where
#                                   activation can bring some non-linearity
#
#                                   so, Activation Function
#                                   should be chosen smartly
#                                   (hyperparameter)

# %% [markdown]
# - ### SOme basic Requirements for Activation function :
#
#
#
#     - should be computationally inexpensive
#     - should be differentiable (some exceptions are there with hack)
#     - should be non-linear
#     - should be centered (some exceptional)

# %% [markdown]
#              w1       w2
#         X--->Z1-A1--->Z2-A2--->J=(y_hat-y) #backpropogate
#              b1       b2

# %% [markdown]
# # Activation Functions :

# %% [markdown]
# - The choice of activation function in the hidden layer will control how well the network model learns the training dataset.
# - The choice of activation function in the output layer will define the type of predictions the model can make.
#
#
# - As such, a careful choice of activation function must be made for each deep learning neural network project.
#
#
#
# - The modern default activation function for hidden layers is the ReLU function.
# - The activation function for output layers depends on the type of prediction problem. like Softmax or sigmoid in classification , linear for regression .

# %% [markdown]
# https://machinelearningmastery.com/choose-an-activation-function-for-deep-learning/

# %% [markdown]
# ### Definition:
# - An activation function in a neural network defines how the weighted sum of the input is transformed into an output from a node or nodes in a layer of the network.
#
#
#
# - Sometimes the activation function is called a “transfer function.”
#
#
#
#
# - If the output range of the activation function is limited, then it may be called a “squashing function.”
#
#
#
# - Many activation functions are nonlinear and may be referred to as the “nonlinearity” in the layer or the network design.
#
#
#
# - The choice of activation function has a large impact on the capability and performance of the neural network, and different activation functions may be used in different parts of the model.
#
#
#
#
# - Technically, the activation function is used within or after the internal processing of each node in the network, although networks are designed to use the same activation function for all nodes in a layer.
#
#
#
#
# - ##### A network may have three types of layers:
#
#     - input layers that take raw input from the domain
#     - hidden layers that take input from another layer and pass output to another layer
#     - output layers that make a prediction.
#
#
#
#
# - All hidden layers typically use the same activation function.
# - The output layer will typically use a different activation function from the hidden layers and is dependent upon the type of prediction required by the model.
#
#
#
# - Activation functions are also typically differentiable, meaning the first-order derivative can be calculated for a given input value.
# - This is required given that neural networks are typically trained using the backpropagation of error algorithm that requires the derivative of prediction error in order to update the weights of the model.
#
#
#
#
# - There are many different types of activation functions used in neural networks, although perhaps only a small number of functions used in practice for hidden and output layers.

# %% [markdown]
# ### Activation for Hidden Layers
#
# - A hidden layer in a neural network is a layer that receives input from another layer (such as another hidden layer or an input layer) and provides output to another layer (such as another hidden layer or an output layer).
#
#
#
# - A hidden layer does not directly contact input data or produce outputs for a model, at least in general.
#
#
#
# - A neural network may have zero or more hidden layers.
#
#
#
# - Typically, a differentiable nonlinear activation function is used in the hidden layers of a neural network.
# - `This allows the model to learn more complex functions than a network trained using a linear activation function`.
#
#
#
# - In order to get access to a much richer hypothesis space that would benefit from deep representations, you need a non-linearity, or activation function.

# %% [markdown]
# ### 1. Linear Activation
#      - A(Z) = Z
#      - in Regression Problem

# %% [markdown]
# ### 2. Step Function :
#
# - The output assumes value 0 for negative argument and 1 for positive argument. The function is as follows:
#
#         A(Z) =  {
#                   1 : if Z > threshold
#                   0 : if Z <= threshold
#                   }

# %%
Z = np.linspace(0,1,100)

# %%
plt.plot(Z)
def step(x, thrshold = 0.5):
    if x > thrshold : return 1
    else: return 0
step = np.vectorize(step)
plt.plot(step(Z))

# %% [markdown]
# ### 3. Sigmoid:
#
# - The main reason why we use sigmoid function is because it exists between (0 to 1).
# - Therefore, it is especially used for models where we have to predict the probability as an output.
# - Since probability of anything exists only between the range of 0 and 1, sigmoid is the right choice.

# %%
Z = np.linspace(-5,5,100)

# %%
def sigmoid(x):
    return 1/ (1+np.exp(-x))

# %%
# plt.plot(Z)
sigmoid = np.vectorize(sigmoid)

# %% [markdown]
# ##### derivative of sigmoid :
#
#         d/(sigmoid(X)) = sig(x)(1-sig(x))
#          dx

# %%
sigmoid = np.vectorize(sigmoid)
plt.plot(sigmoid(Z))  
plt.plot(sigmoid(Z)*(1-sigmoid(Z)))
plt.show()

# %% [markdown]
# ### 4. SoftMax:
#
#     softmax is not just a function of one parameter,
#     but it also take other class neuron's output into account

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def softmax(Z):
    return np.exp(Z) / np.sum((np.exp(Z)))

Z = np.array([0.2,0.5,0.99])

probs = softmax(Z)

# report the probabilities
print(probs)
# report the sum of the probabilities
print("Sum of probabilities: ",probs.sum())
# Out:
# [0.21962309 0.29646017 0.48391674]
# Sum of probabilities:  1.0

# %% [markdown]
# ### 5. Tanh Hidden Layer Activation Function
#
#
# - The hyperbolic tangent activation function is also referred to simply as the Tanh (also “tanh” and “TanH“) function.
#
# -  very similar to the sigmoid activation function
#
# - The Tanh activation function is calculated as follows:
#
#         (e^x – e^-x) / (e^x + e^-x)

# %%
def tanh(x):
    numerator = np.exp(x) - np.exp(-x)
    denominator  = np.exp(x) + np.exp(-x)
    return numerator/ denominator

# %%
Z = np.linspace(-10,10,100)
tanh = np.vectorize(tanh)
plt.plot(tanh(Z))  

plt.show()

# %%
def tanh(x):
    numerator = np.exp(x) - np.exp(-x)
    denominator  = np.exp(x) + np.exp(-x)
    return numerator/ denominator

# %%
# first derivative of tanh

# %%
Z = np.linspace(-10,10,100)
tanh = np.vectorize(tanh)
plt.plot(tanh(Z))  
plt.plot(1-(tanh(Z)**2))

plt.show()

# %% [markdown]
# ### 6. ReLU Hidden Layer Activation Function
# - ### rectified linear Unit
#
# - `The rectified linear Unit activation function`, or `ReLU` activation function, is perhaps the most common function used for hidden layers.
#
#
# - It is common because it is both simple to implement and effective at overcoming the limitations of other previously popular activation functions, such as Sigmoid and Tanh.
# - Specifically, it is `less susceptible to vanishing gradients that prevent deep models from being trained`, although it `can suffer from other problems like saturated or “dead” units`.
#     - because , when value is lesser than threshold, the derivative becomes 0. make the neuron  dead
#
#
# - The ReLU function is calculated as follows:
#
#         - max(0.0, x)
#
# - This means that if the input value (x) is negative, then a value 0.0 is returned, otherwise, the value is returned.

# %%
def relu(x):
    
    return max(0,x)
relu = np.vectorize(relu)

Z = np.arange(-10,15)
plt.plot(relu(Z))  
plt.show()

# %% [markdown]
# ###  7. Leaky ReLU

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def Leaky_relu(x,alfa=0.1):
    if x < 0 :
        return alfa*x
    else:
        return x
Leaky_relu = np.vectorize(Leaky_relu)

Z = np.arange(-10,10)
plt.plot(Leaky_relu(Z))  
plt.show()

# %%
def elu(x,alfa=1):
    if x <= 0 :
        return alfa*(np.exp(x)-1)
    else:
        return x
elu = np.vectorize(elu)

Z = np.arange(-10,10)

plt.plot(elu(Z))  
plt.hlines(y = 0,xmin = 0, xmax =20,color="grey")
plt.show()

# %% [markdown]
# https://en.wikipedia.org/wiki/Activation_function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Pros and Cons of Activation Functions

# %% [markdown]
# https://www.linkedin.com/pulse/top-10-activation-functions-advantages-disadvantages-dash/

# %% [markdown]
# #### Sigmoid:-
#
# - Normally used as the output of a binary probabilistic function.
#
# - Advantages:
#
#     - Gives you a smooth gradient while converging.
#     - One of the best Normalised functions.
#     - Gives a clear prediction(classification) with 1 & 0.
#
# - Disadvantages:
#
#     - Prone to Vanishing Gradient problem.
#     - Not a zero-centric function(Always gives a positive values).
#     - Computationally expensive function(exponential in nature).
#
#
#
# #### Tanh:-
#
# - Normally used as the input of a binary probabilistic function.
#
# - Advantages:
#
#     - Zero-centric function unlike Sigmoid.
#     - It is a smooth gradient converging function.
#
# - Disadvantages:
#
#     - Prone to Vanishing Gradient function.
#     - Computationally expensive function(exponential in nature).
#
# #### RELU:-(Rectified Linear Unit)
#
# - Advantages:
#
#     - Can deal with Vanishing Gradient problem.
#     - Computationally inexpensive function(linear in nature).
#
# - Disadvantages:
#     - Not a zero-centric function.
#     - Gives zero value as inactive in the negative axis.
#
# #### Leaky RELU:-
#
# - It is the same as of RELU function except it gives some partial value(0.01 instead zero as of RELU) in the negative axis.
#
# #### ELU:- (Exponential Linear Unit)
#
# - Advantages:
#
#     - Gives smoother convergence for any negative axis value.
#     - For any positive output, it behaves like a step function and gives a constant output.
#
# #### SoftMax:-
#
# - Normally used as the output in multi-class classification problems to find out different probabilities for different classes(Unlike Sigmoid which is prefered for a binary-class classification).
#
# #### PRELU:- (Parametric RELU)
#
# - The advantage of PRELU is it has the learning parameter function which fine-tunes the activation function based on its learning rate(unlike zero in the case of RELU and 0.01 in the case of Leaky RELU).
#
# #### SWISH:-
#
# - Also known as self gated function. This activation function is one of the kinds that is being inspired by the use of the Sigmoid function inside an LSTM(Long Short Term Memory) based network.
#
# - Advantages:
#
#     - Can deal with Vanishing Gradient problem.
#     - The output is a workaround between RELU and Sigmoid function which helps in normalising the output.
#
# - Disadvantage:
#
#     - Computationally expensive function (as of Sigmoid).
#
#
# #### MaxOut:-
#
# - Also known as the Learnable Activation Function.
# - It has all the advantages of a RELU function but at the same time do not have its disadvantages.
#
# #### SoftPlus:-
#
# - Advantages:
#     - Convergence of gradient is smoother than RELU function.
#     - It can handle the Vanishing Gradient problem.
#
# - Disadvantage:
#
#     - Computationally expensive than RELU(as of exponential in nature).

# %% [markdown]
# # N-Layer NN:

# %% [markdown]
# ## Notations for N layer NN
#
#
# So, we introduce layer number in notation as superscript
#
# Now,
# As layer increase, earlier weight notation will not work.
# - So, we add layer number to weight notation as well.
#
#
#
#
# For weight: $w^L_{ij}$
#
# where
# - L represent layer number
# - and i represents from neuron
# - j represent to neuron
#
# <br>
#
# Bias: $b^L_i$
# where
# - L represents the layer
# - i represents the neuron.
#
#
# <center><img src='https://drive.google.com/uc?id=1LAnU_9qgGqf9LbK1PzotW6J80WRYb9Rx' width="800"></center>

# %% [markdown]
# We will now have two sets of weights and biases (for the first and second layers) - $W^1, W^2, b^1, b^2$
#
# <br>
#
# #### What will be the dimensions of the parameters $W^1, b^1, W^2, b^2$?
#
#
# Forget about the second layer for now, let's just focus on the first layer, and it's inputs.
#
# <br>

# %% [markdown]
# #### $W^1$
# - Here, we have **2 inputs** being passed to **4 neurons**
# - Recall that each pair of input and neuron, has a unique weights value.
# - Therefore, $W^1$ will be $2\times4$ matrix:
# $W^1 = \begin{bmatrix}
# w_{11}^1 & w_{12}^1 & w_{13}^1 & w_{14}^1\\
# w_{21}^1 & w_{22}^1 & w_{23}^1 & w_{24}^1
# \end{bmatrix}_{2 \times 4}$
#
# <br>
#
# #### $b^1$
# - There are 4 neurons in the first layer.
# - Each of which has an unique bias value.
# - Therefore, $b^1$ will be $1 \times 4$ matrix: $b^1 = \begin{bmatrix}
# b_1^1 & b_2^1 & b_3^1 & b_4^1
# \end{bmatrix}_{1 \times 4}$

# %% [markdown]
# Let's figure dimensions $W^2$ and $b^2$ by considering only layer-1 and layer-2 again as a one layer NN
#
#
# #### $W^2$
# - Now, the outputs of the layer-1 are inputs to the layer-2.
# - Layer-2 neurons don't need to know if its an output from an earlier layer, or a raw input
# - Here, 4 inputs are passed to 3 neurons, $W^2$ will be $4\times3$ matrix: $W^2 = \begin{bmatrix}
# w_{11}^2 & w_{12}^2 & w_{13}^2\\
# w_{21}^2 & w_{22}^2 & w_{23}^2\\
# w_{31}^2 & w_{32}^2 & w_{33}^2\\
# w_{41}^2 & w_{42}^2 & w_{43}^2
# \end{bmatrix}_{4 \times 3}$
#
# <br>
#
# #### $b^2$
# - There are 3 neurons in second layer, each of which will have a bias associated with them.
# - Therefore, $b^2$ will be $1 \times 3$ matrix: $b^2 = \begin{bmatrix}
# b_1^2 & b_2^2 & b_3^2
# \end{bmatrix}_{1 \times 3}$

# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1bqb4oQMnmIDprSb2MSlmDNeJTpJfwW-N' width="700"></center>

# %% [markdown]
# ### Forward Propogation :
#
# Now, we need to calculate $Z^1$,
# - for this we multiply each row of X with each column of W1
# - add bias to it (using broadcasting)
#
#
# The formulation comes out to be:
#
# $$X.W + b$$

# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=19PU6SUdkaIcJtA6VQbsC1GMAzTMCv_lx' width="700"></center>

# %% [markdown]
# ### Loss
#
# ####  Will the loss change?
#
# No
#
# ### Backpropagation
#
# #### Will the gradient calculation change?
#
# No, but, we would have to backpropagate the gradients for one additional layer.

# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=13P54Hx1Jgdd6E5gX2g1q1F8qYIhYzZP6' width="700"></center>

# %% [markdown]
# $$dZ^2 = \frac{∂L}{∂Z^2}$$
#
#
# So,
#
# $$\frac{∂L}{∂Z^2} = \frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2}$$
#
# Here, $A^2$ is our output probabilities.
# - Replaceing $A^2$ with $p$
#
# $$\frac{∂L}{∂Z^2} = \frac{∂L}{∂p}.\frac{∂p}{∂Z^2}$$
#
# #### Doesn't this look familiar ?
#
# - This is similar to what we calculated previously i.e derivative of Loss w.r.t to Z
#
# $$dz=\frac{\partial J}{\partial p} \frac{\partial p}{\partial z}$$
#
# - The derivative came out to be : $dz = (p_i - I (i=y))$
#
#
# Hence, $dZ_2 = (p_i - I (i=y))$

# %% [markdown]
# As dZ2 is same as probabilties,
# - its shape will be (m,3) or (300, 3)

# %% [markdown]
# #### Calculating $dW^2$ and $db^2$
#
#
# Gradient calculation for $dW^2$ and $db^2$ will also be similar to $dW$ and $db$ in the softmax classifier case

# %% [markdown]
# $$dW^2 = \frac{∂L}{∂W^2} = \frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2}.\frac{∂Z^2}{∂W^2}$$
#
# $$= dZ^2.\frac{∂Z^2}{∂W^2}$$
#
# Here, $Z^2 = W^{2^{T}}.A^1 + b^2$
#
# So, $\frac{∂Z^2}{∂W^2} = A^1$
#
# $$dW^2 = \frac{∂L}{∂W^2} = dZ^2 . A^1$$

# %% [markdown]
# $$db^2 = \frac{∂L}{∂b^2} = \frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2}.\frac{∂Z^2}{∂b^2}$$
#
# Now,
#
# $$\frac{∂Z^2}{∂b^2} = \frac{∂(W^2A^1 + b^2)}{db^2} = 1$$
#
# $$db^2 = \frac{∂L}{∂b^2} = \frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2}.1 = dZ^2$$

# %% [markdown]
# $$dA^1 = \frac{∂L}{∂A^1} = \frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2}.\frac{∂Z^2}{∂A^1}$$
#
#
# We know that, $$\frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2} = dZ^2$$
#
# Now,
#
# $$\frac{∂Z^2}{∂A^1} = \frac{∂(W^2A^1 + b^2)}{dA^1} = W^2$$
#
#
# $$dA^1 =\frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2}.W^2 = dZ^2.W^2$$

# %% [markdown]
# $$ \frac{∂L}{∂Z^1} = \frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2}.\frac{∂Z^2}{∂A^1}.\frac{∂A^1}{∂Z^1}$$
#
# We know that,
#
# $$\frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2}.\frac{∂Z^2}{∂A^1} = dA^1 $$
#
#
# We have to calculate $\frac{∂A^1}{∂Z^1}$

# %% [markdown]
# $$ \frac{∂L}{∂W^1} = \frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2}.\frac{∂Z^2}{∂A^1}.\frac{∂A^1}{∂Z^1}.\frac{∂Z^1}{∂W^1}$$
#
# We know that,
#
# $$\frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2}.\frac{∂Z^2}{∂A^1}.\frac{∂Z^1}{∂A^1} = dZ^1 $$
#
#
# We have to calculate $\frac{∂Z^1}{∂W^1}$
#
# $$\frac{∂Z^1}{∂W^1} = \frac{∂(W^1.X + b^1)}{∂W^1} = X $$
#
#
# So,
#
# $$ \frac{∂L}{∂W^1} = dZ^1.X$$

# %% [markdown]
# $$ \frac{∂L}{∂b^1} = \frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2}.\frac{∂Z^2}{∂A^1}.\frac{∂A^1}{∂Z^1}.\frac{∂Z^1}{∂b^1}$$
#
# We know that,
#
# $$\frac{∂L}{∂A^2}.\frac{∂A^2}{∂Z^2}.\frac{∂Z^2}{∂A^1}.\frac{∂Z^1}{∂A^1} = dZ^1 $$
#
#
# We have to calculate $\frac{∂Z^1}{∂b^1}$
#
# $$\frac{∂Z^1}{∂b^1} = \frac{∂(W^1.X + b^1)}{∂b^1} = 1 $$
#
#
# So,
#
# $$ \frac{∂L}{∂b^1} = dZ^1.1$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     # Forward Propogation
#
#     Z1 : w1X+b1
#     A1 : max(0,Z1)   # Relu activation
#     Z2 : w2A1 + b2
#     A2 : softmax(Z2)  # softmax to all probabilities
#
#
#
#
#     A2 : softmax(w2(max(0,w1X+b1)) + b2)
#
#
#     Loss:
#
#     J =  -1     n
#         ----   SUM  Yi * log(A2i)
#          n     i=1
#
#
#     # Backward Propogation
#
#                 dZ2_dw2              dZ1_dW1
#     dJ_dA2 * dA2_dZ2 * dZ2_dA1 * dA1_dZ1
#                 dZ2_db2              dZ1_db1
#
#
#
#     dJ_dA2 = A2-Y
#     dZ2_dw2 = A1          w2 = w2- eta* dJ_dw2
#
#
#                            dJ_dw2 = dJ_dA2 * dA2_dZ2 * dZ2_dw2
#                                   =     (A2-Y)       * A1
#                                         (n,3)      (n,4)
#
#                                      np.dot((A1.T) , (A2-Y)) / n
#                                       shape : (4,3)
#
#
#
#     dZ2_db2 = 1
#                           dJ_db2 = dJ_dA2 * dA2_dZ2 * dZ2_db2
#                                  =      (A2-y)      *   1
#                                   shapes:(n,3)
#
#                                   in code: np.mean(A2-y) axis = 0

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv("spiral.csv")
df.head()
# Out:
#          x1        x2  y
# 0  0.000000  0.000000  0
# 1 -0.000650  0.010080  0
# 2  0.009809  0.017661  0
# 3  0.007487  0.029364  0
# 4 -0.000027  0.040404  0

# %%
plt.scatter(df["x1"], df["x2"], c=df["y"], s=40, cmap=plt.cm.Spectral)
plt.show()

# %%
df.shape
# Out:
# (300, 3)

# %%
X = df.iloc[:,:-1].to_numpy()
y = df.iloc[:,-1].to_numpy()

d = X.shape[1]  # diensionality / number of inputs
n = len(X)
k = len(np.unique(y))  #  Number of classes (A/B/C) / 
                      # Number of neurons in output layer

# %%
d,n,k
# Out:
# (2, 300, 3)

# %%
h = 4 # neurons in hidden layer

# %%
w1 = 0.01 * np.random.randn(d,h)
w2 = 0.01 * np.random.randn(h,k)

b1 = np.zeros((1,h))
b2 = np.zeros((1,k))

# %%
w1
# Out:
# array([[ 0.00782791,  0.00331894, -0.00569092, -0.00787443],
#        [ 0.01728083,  0.0072498 ,  0.01415738, -0.00054278]])

# %%
w2
# Out:
# array([[ 0.00781891,  0.00306737,  0.00262676],
#        [ 0.00964458, -0.01136935, -0.02238718],
#        [ 0.01430161, -0.00781466,  0.00802877],
#        [-0.00947813,  0.00974668,  0.0027008 ]])

# %%
b1,b2
# Out:
# (array([[0., 0., 0., 0.]]), array([[0., 0., 0.]]))

# %%
y = pd.get_dummies(y).to_numpy()
y.shape
# Out:
# (300, 3)

# %%
# Forward Propogation : 

Z1 = np.dot(X,w1) + b1
A1 = np.maximum(0,Z1)    # Relu

# %%
Z2 = np.dot(A1,w2) + b2
A2 = np.exp(Z2) / np.sum(np.exp(Z2),axis = 1, keepdims=True)  # Softmax

# %%
probs = A2   # y_hat

# %%
# Loss

def loss(y, probs):
    n = y.shape[0]
    error = -(np.log(probs)*y)   # categorical_entropy 
    return np.sum(error)/n
loss(y, probs)
# Out:
# 1.0986261627997091

# %%
# Backward Propogation :

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
# dZ2  = A2-Y
# dA1 , dZ1 , dw1

# %%
dJ_dZ2 = (probs - y) / n   # A2- y

dJ_dw2 = np.dot(A1.T,dJ_dZ2) 

dJ_db2 = np.sum(dJ_dZ2, axis = 0, keepdims=True)

dJ_dA1 = np.dot(dJ_dZ2 , w2.T)

dJ_dA1[Z1 < 0] = 0 # relu , derivative 
dJ_dZ1 = dJ_dA1

dJ_dw1 = np.dot(X.T,dJ_dZ1)
dJ_db1 = np.sum(dJ_dZ1, axis = 0, keepdims=True)

# %%
# w1 = w1 - lr* dJ_dw1   # update at each epochs
# b1 = b1 - lr* dJ_db1
# w2 = w2 - lr* dJ_dw2
# b2 = b2 - lr* dJ_db2

# %% [markdown]
# ## Code : for n-layer NN

# %%
class n_layer_NN_classifier:
    
    def __init__(self,n_features, n_hidden, n_classes):
        self.d = n_features
        self.h = n_hidden
        self.k = n_classes
        self.w1 = 0.01 * np.random.randn(self.d,self.h)
        self.w2 = 0.01 * np.random.randn(self.h,self.k)
        self.b1 = np.zeros((1,self.h))
        self.b2 = np.zeros((1,self.k))
        
    def Forward_propogation(self,X):
        Z1 = np.dot(X,self.w1) + self.b1
        A1 = np.maximum(0,Z1)
        
        Z2 = np.dot(A1, self.w2) + self.b2
        Z2 = np.exp(Z2)
        A2 = Z2 / np.sum(Z2, axis = 1, keepdims=True) 
        return A1,A2
    
    def Categorical_entropy(self,probs,y):
        y = pd.get_dummies(y).to_numpy()
        n = y.shape[0]
        
        entropy = np.sum((np.sum(-(np.log(probs)*y) , axis = 0))) / n
        return  entropy
    
    def BackwardPropogation(self,X,A1,A2,y):
        y = pd.get_dummies(y).to_numpy()
        n = y.shape[0]
        
        
        dJ_dZ2 = A2 - y    # A2- y
        dJ_dZ2 = dJ_dZ2/n

        dJ_dw2 = np.dot(A1.T,dJ_dZ2) 

        dJ_db2 = np.sum(dJ_dZ2, axis = 0, keepdims=True)

        dJ_dA1 = np.dot(dJ_dZ2 , self.w2.T)

        dJ_dA1[A1 < 0] = 0 # relu , derivative 
        dJ_dZ1 = dJ_dA1

        dJ_dw1 = np.dot(X.T,dJ_dZ1)
        dJ_db1 = np.sum(dJ_dZ1, axis = 0, keepdims=True)

        return dJ_dw1,dJ_db1,dJ_dw2,dJ_db2
    
    def fit(self,X,lr,reg,max_iters):
        
        n = X.shape[0]
        for i in range(max_iters):
            A1,A2 = self.Forward_propogation(X)
            # Calculate Loss:
            loss = self.Categorical_entropy(A2,y)
          
            if i %1000 == 0:
                print(f"{i}th iteration: loss:{loss}")
                
          
        
            dJ_dw1,dJ_db1,dJ_dw2,dJ_db2 = self.BackwardPropogation(X,A1,A2,y)
        
        
            # add regularization gradient contribution
            dJ_dw2 += reg * self.w2
            dJ_dw1 += reg * self.w1
        
            
            self.w1 = self.w1 - lr* dJ_dw1
            self.b1 = self.b1 - lr* dJ_db1
            
            self.w2 = self.w2 - lr* dJ_dw2
            self.b2 = self.b2 - lr* dJ_db2
            
        return w1,b1,w2,b2
            
    def predict(self,X):
        A1 = np.maximum(0,np.dot(X,self.w1) + self.b1)
        Z2 = np.dot(A1,self.w2) + self.b2
        return np.argmax(Z2,axis = 1)

# %%
X = df.iloc[:,:-1].to_numpy()
y = df.iloc[:,-1].to_numpy()

# %%
class NN:
    
    def __init__(self, n_features, n_hidden, n_classes):
        self.d = n_features
        self.h = n_hidden
        self.k = n_classes
        self.W1 = 0.01 * np.random.randn(self.d, self.h)
        self.b1 = np.zeros((1,self.h))
        self.W2 = 0.01 * np.random.randn(self.h,self.k)
        self.b2 = np.zeros((1,self.k))
     
    def fwd_prop(self, X):
        Z1 = np.dot(X, self.W1) + self.b1
        A1 = np.maximum(0, Z1)
        Z2 = np.dot(A1, self.W2) + self.b2
        Z2 = np.exp(Z2)
        A2 = Z2 / np.sum(Z2, axis=1, keepdims=True)
        return A1, A2
    
    def cce_loss(self, y, probs):
        n = len(y)
        loss = np.sum((np.sum(-(np.log(probs)*y) , axis = 0))) / n

        return loss  
    
    def back_prop(self, X, A1, A2, y):
        # compute the gradient on scores
        n = len(y)
        dJ_dZ2 = A2 - y
        dJ_dZ2 /= n
        
        # first backprop into parameters W2 and b2
        dJ_dW2 = np.dot(A1.T, dJ_dZ2)
        dJ_db2 = np.sum(dJ_dZ2, axis=0, keepdims=True)
        
        # next backprop into hidden layer, A1
        dJ_dA1 = np.dot(dJ_dZ2, self.W2.T)
        
        # backprop the ReLU non-linearity
        dJ_dA1[A1 <= 0] = 0
        
        dJ_dZ1 = dJ_dA1
        dJ_dW1 = np.dot(X.T, dJ_dZ1)
        dJ_db1 = np.sum(dJ_dZ1, axis=0, keepdims=True)
        
        return dJ_dW1, dJ_db1, dJ_dW2, dJ_db2       
    
    def fit(self, X,y, lr, reg, max_iters):
        n = X.shape[0]
        y = pd.get_dummies(y).to_numpy()
        
        for i in range(max_iters):
            #foward prop
            A1, A2 = self.fwd_prop(X)
            # calculate loss
            data_loss = self.cce_loss(y, A2)
            reg_loss = 0.5*reg*np.sum(self.W1*self.W1) + 0.5*reg*np.sum(self.W2*self.W2)
            loss = data_loss + reg_loss
            
            if i % 1000 == 0:
                print("iteration %d: loss %f" % (i, loss))
        
            dJ_dW1, dJ_db1, dJ_dW2, dJ_db2  = self.back_prop(X, A1, A2, y)

            # add regularization gradient contribution
            dJ_dW2 += reg * self.W2
            dJ_dW1 += reg * self.W1

            # perform a parameter update
            self.W1 += -lr * dJ_dW1
            self.b1 += -lr * dJ_db1
            self.W2 += -lr * dJ_dW2
            self.b2 += -lr * dJ_db2
        
    def predict(self, X):
        A1 = np.maximum(0, np.dot(X, self.W1) + self.b1) # ReLU(Z1) = ReLU(W1T. X + b1)
        Z2 = np.dot(A1, self.W2) + self.b2 # Z2 = W2T.A1 + b2 => 3 probab
        y_hat = np.argmax(Z2, axis=1) # taking index of max probab
        return y_hat
    
nn_model = NN(n_features=2, n_hidden=100, n_classes=3)
nn_model.fit(X,y, lr=1, reg=1e-3, max_iters=10000)
print('training accuracy: %.2f' % (np.mean(nn_model.predict(X) == y)))
# Out:
# iteration 0: loss 1.098627
# iteration 1000: loss 0.323654
# iteration 2000: loss 0.257076
# iteration 3000: loss 0.250958
# iteration 4000: loss 0.249515
# iteration 5000: loss 0.248517
# iteration 6000: loss 0.247716
# iteration 7000: loss 0.247451
# iteration 8000: loss 0.247345
# iteration 9000: loss 0.247292
# training accuracy: 0.99

# %%
# create a 2D grid
step = 0.02
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, step), np.arange(y_min, y_max, step))

# predict for all the points in the grid

y_hat = nn_model.predict(np.c_[xx.ravel(), yy.ravel()])
y_hat = y_hat.reshape(xx.shape)

# plot
fig = plt.figure()
plt.contourf(xx, yy, y_hat, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.show()
